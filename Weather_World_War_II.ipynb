# %% [markdown]
# <a href="https://colab.research.google.com/github/AlwaysDayana/Weather-World-War-II/blob/main/Weather_World_War_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_weather =pd.read_csv("/content/drive/MyDrive/WW_Weather/Summary of Weather.csv")
# Out:
# <ipython-input-14-4c21aff00f23>:1: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_weather =pd.read_csv("/content/drive/MyDrive/WW_Weather/Summary of Weather.csv")

# %% [markdown]
# # Description of dataset and variables.

# %%
print(df_weather.shape)
df_weather.head()
# Out:
# (119040, 31)
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556
# 2  10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall PoorWeather  YR  ...  FB  FTI ITH  PGT  TSHDSBRSGF  SD3  RHX  RHN  \
# 0      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 1      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 2      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 3      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 4      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
#
#   RVG  WTE
# 0 NaN  NaN
# 1 NaN  NaN
# 2 NaN  NaN
# ...

# %% [markdown]
# The dataset contains 119,040 rows and 31 columns. From the header we can see many incidences of missing values.
#
# From 31 columns, 9 have not null values.
#
# - STA
# - Date
# - Precip
# - MaxTemp
# - MinTemp
# - MeanTemp
# - YR
# - MO
# - DA

# %%
print(df_weather.describe())
df_weather.describe(include=["object", "int"])
# Out:
#                  STA  WindGustSpd        MaxTemp        MinTemp  \
# count  119040.000000   532.000000  119040.000000  119040.000000
# mean    29659.435795    37.774534      27.045111      17.789511
# std     20953.209402    10.297808       8.717817       8.334572
# min     10001.000000    18.520000     -33.333333     -38.333333
# 25%     11801.000000    29.632000      25.555556      15.000000
# 50%     22508.000000    37.040000      29.444444      21.111111
# 75%     33501.000000    43.059000      31.666667      23.333333
# max     82506.000000    75.932000      50.000000      34.444444
#
#             MeanTemp             YR             MO             DA          DR  \
# count  119040.000000  119040.000000  119040.000000  119040.000000  533.000000
# mean       22.411631      43.805284       6.726016      15.797530   26.998124
# std         8.297982       1.136718       3.425561       8.794541   15.221732
# ...

# %% [markdown]
# From 31 columns, 9 have not null values.
# - STA
# - Date
# - Precip
# - MaxTemp
# - MinTemp
# - MeanTemp
# - YR
# - MO
# - DA

# %% [markdown]
# ## Integers columns

# %%
df_weather.describe(include=["int"])
# Out:
#                  STA             YR             MO             DA
# count  119040.000000  119040.000000  119040.000000  119040.000000
# mean    29659.435795      43.805284       6.726016      15.797530
# std     20953.209402       1.136718       3.425561       8.794541
# min     10001.000000      40.000000       1.000000       1.000000
# 25%     11801.000000      43.000000       4.000000       8.000000
# 50%     22508.000000      44.000000       7.000000      16.000000
# 75%     33501.000000      45.000000      10.000000      23.000000
# max     82506.000000      45.000000      12.000000      31.000000

# %% [markdown]
# STA, YR, MO, DA are integers data types. All of them have non missing values.

# %%
df_weather_sta = df_weather['STA'].value_counts().head(20)

df_weather_sta.sort_values(ascending=False).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ## Continuous (float) variables

# %%
df_weather.describe(include=["float"])
# Out:
#        WindGustSpd        MaxTemp        MinTemp       MeanTemp          DR  \
# count   532.000000  119040.000000  119040.000000  119040.000000  533.000000
# mean     37.774534      27.045111      17.789511      22.411631   26.998124
# std      10.297808       8.717817       8.334572       8.297982   15.221732
# min      18.520000     -33.333333     -38.333333     -35.555556    2.000000
# 25%      29.632000      25.555556      15.000000      20.555556   11.000000
# 50%      37.040000      29.444444      21.111111      25.555556   32.000000
# 75%      43.059000      31.666667      23.333333      27.222222   34.000000
# max      75.932000      50.000000      34.444444      40.000000   78.000000
#
#               SPD            MAX            MIN            MEA     SND   FT  \
# count  532.000000  118566.000000  118572.000000  118542.000000  5563.0  0.0
# mean    20.396617      81.003745      64.273808      72.644843     0.0  NaN
# ...

# %% [markdown]
# WindGustSpd, MaxTemp, MinTemp, MeanTemp, DR, SPD, MAX, MIN, MEA, SND, FT, FB have continuous data type.
